# %% [markdown]
# # Kaggle_COVIDTRACKING_Dataset(케글 코로나추적 데이터셋)
# - 미국의 주요 신문사에서 사용하는 코로나추적 데이터셋, 본 페이지. https://covidtracking.com/data/download
#
# 주요 컬럼
# - deathIncrease : 오늘과 전날간의 사망자 증가량
# - hospitalizedIncrease : 입원환자 증가량
# - negativeIncrease : 음성확진 증가량
# - PositiveIncrease : 양성판정 증가량

# %%
import pandas as pd 
df = pd.read_csv('daily.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ae51cd54d120> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('daily.csv')
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
# 'deathIncrease','hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease' 컬럼 
fix_data = df.loc[:, ['date','deathIncrease','hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease']]  # 전체 행 + 지정컬럼
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-834d45938cdc> in <module>()
#       1 # 'deathIncrease','hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease' 컬럼
# ----> 2 fix_data = df.loc[:, ['date','deathIncrease','hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease']]  # 전체 행 + 지정컬럼
#
# NameError: name 'df' is not defined

# %%
fix_data.info()

# %%
# date가 int64? -> 시각화 가능하도록 str 형태로
fix_data = fix_data.astype({'date':'str'})

# %%
# 날짜 str 확인
fix_data.info()

# %%
# 날짜로 index
fix_data.set_index('date', inplace=True)

# %%
fix_data.head()

# %%
# 시각화 설정
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %config InlineBackend.figure_format = 'retina' # 그래프의 글자 선명하게
# !apt -qq -y install fonts-nanum  # 나눔 글자체 설치
#나눔고딕 글자체의 전체 경로 설정
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
#글자체의 경로와 글자 크기 설정
font = fm.FontProperties(fname=fontpath, size=9)
#폰트 이름 설정
plt.rc('font', family='NanumBarunGothic') 
#폰트 업데이트
mpl.font_manager._rebuild()

# %%
plt.figure(figsize=(20,10))

# 날짜를 과거부터 최근 순서로
fix_data.sort_values(by='date', inplace=True)

# %%
#폰트 이름 설정
plt.rc('font', family='cambria', size=9) 
#폰트 업데이트
mpl.font_manager._rebuild()
plt.style.use('ggplot')

# layout() 통해서 2개로 나누기!
fix_data.plot(subplots=True, layout=(2,2), figsize=(15,12))
plt.savefig('keggle_us_data.png', dpi=300)
