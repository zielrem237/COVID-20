# %%
#구글 드라이브 연결
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#그래프의 전체적인 설정을 하는 객체
import matplotlib as mpl
#그래프를 그리는 객체
import matplotlib.pyplot as plt

# %%
#그래프의 글자를 선명하게 출력하도록 설정 
# %config InlineBackend.figure_format = 'retina'
#나눔 글자체 설치 
# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import matplotlib.font_manager as fm
#나눔고딕 글자체의 전체 경로 설정
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
#글자체의 경로와 글자 크기 설정
font = fm.FontProperties(fname=fontpath, size=9)

# %%
#폰트 이름 설정
plt.rc('font', family='NanumBarunGothic') 
#폰트 업데이트
mpl.font_manager._rebuild()

# %%
#20200120~20200720까지의 "코로나 블루" 언급, 관련 기사 불러오기
df = pd.read_csv("/gdrive/My Drive/2020aicurator/Cdata/news.csv")

# %%
#불러온 뉴스 파일
df
# Out:
#             뉴스 식별자  ...  분석제외 여부
# 0     2.100801e+06  ...      NaN
# 1     2.100851e+06  ...      NaN
# 2     2.100851e+06  ...      NaN
# 3     1.400201e+06  ...      NaN
# 4     1.100611e+06  ...      NaN
# ...            ...  ...      ...
# 1572  2.100851e+06  ...      NaN
# 1573  2.100801e+06  ...      NaN
# 1574  1.600801e+06  ...      NaN
# 1575  1.101101e+06  ...      NaN
# 1576  1.600801e+06  ...      NaN
#
# [1577 rows x 19 columns]

# %%
#제거할 컬럼들
code = ["뉴스 식별자", "기고자", "언론사", "본문", "통합 분류1", "통합 분류2", "통합 분류3", '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', 'URL', '분석제외 여부']

#컬럼 제거
df.drop(code, axis=1, inplace=True)

df
# Out:
#             일자  ...                                  특성추출(가중치순 상위 50개)
# 0     20200720  ...  로고라이트,자곡동,빛글씨,강남구,3개소,공승호,코로나19,압구정,개포,주민들,15대...
# 1     20200720  ...  코로나19,어촌체험휴양마을,돌미역,어촌어항공단,탐방로,한국어촌어항공단,수산물,부산,...
# 2     20200720  ...  농촌체험휴양마을,코로나19,보은,경기도,우울감,편백나무,6곳,농촌관광,전라남도,잘산...
# 3     20200720  ...  코로나19,한의학,우리나라,뉴노멀,불안감,건강관리,정신건강,정신질환,칠정,회원국,연...
# 4     20200720  ...  관악구,코로나19,힐링,관악산,체험원,코로나,힐링공간,쉼터,1만,박준희,신림선,서울...
# ...        ...  ...                                                ...
# 1572  20200204  ...  쇼케이스,공연장,빅히트,소속사,설명회,넷플릭스,걸그룹,김태우,제작발표회,미니앨범,코...
# 1573  20200204  ...  소비자,판매자,1만,자장면,퍼실파워젤,헨켈홈케어코리아,생필품,세정제,오픈마켓,서울,...
# 1574  20200203  ...  중국,코로나바이러스,월드투어,우한,세계실내육상선수권대회,개최지,lpga,난징,한국시...
# 1575  20200129  ...                    한국,사업단,코르동,원경,런던,문화원,영국,서울,전통문화
# 1576  20200129  ...  전남,블루이코노미,전남도,전남도청,김영록,중국발,사업들,30여분,단체장들,단체장,출...
#
# [1577 rows x 4 columns]

# %%
#일자를 날짜 YYYY-MM-DD 형식으로 변환해서 date라는 컬럼을 새로 생성.
df['date'] = df['일자'].apply(lambda x: pd.to_datetime(str(int(x)), format='%Y%m%d')) 
df.head()
# Out:
#          일자  ...       date
# 0  20200720  ... 2020-07-20
# 1  20200720  ... 2020-07-20
# 2  20200720  ... 2020-07-20
# 3  20200720  ... 2020-07-20
# 4  20200720  ... 2020-07-20
#
# [5 rows x 5 columns]

# %%
#컬럼제거
c = ["특성추출(가중치순 상위 50개)", "일자"]

df.drop(c, axis=1, inplace=True)

# %%
#기사와 관련된 키워드비율을 나타낸 워드클라우드 이미지 불러오기
import matplotlib.pyplot as plt

plt.figure(figsize=(20,6))
a = plt.imread('/gdrive/My Drive/2020aicurator/Cdata/연관어분석_20200721.png')
plt.imshow(a)

# %%
#워드 클라우드를 바탕으로 키워드 선택 & 임의로 키워드 설정
#코로나 블루와 관련된 키워드를 선택하고자 했습니다
#키워드가 나오는 기사의 개수

df_keyword = pd.DataFrame({
    "우울" : [df["키워드"].str.contains("우울감").sum()+df["키워드"].str.contains("우울증").sum()],
    "불안감" : [df["키워드"].str.contains("불안감").sum()],
    "힐링" : [df["키워드"].str.contains("힐링").sum()],
    "심리방역" : [df["키워드"].str.contains("심리방역").sum()+df["키워드"].str.contains("심리건강").sum()],
    "집콕" : [df["키워드"].str.contains("집콕").sum()],
    "고립감" : [df["키워드"].str.contains("고립감").sum()],
    "스트레스" : [df["키워드"].str.contains("스트레스").sum()],
    "거리두기" : [df["키워드"].str.contains("거리").sum()]  
})

# %%
#행과 열을 바꿔주기
df_keyword = df_keyword.T
print(df_keyword)
# Out:
#         0
# 우울    851
# 불안감   228
# 힐링    169
# 심리방역   73
# 집콕    137
# 고립감    67
# 스트레스  425
# 거리두기  722

# %%
#키워드별 언급된 기사개수를 "count"라는 컬럼명으로 변경
df_keyword.columns = ["count"]
df_keyword
# Out:
#       count
# 우울      851
# 불안감     228
# 힐링      169
# 심리방역     73
# 집콕      137
# 고립감      67
# 스트레스    425
# 거리두기    722

# %%
#원그래프로 시각화
df_keyword["count"].plot(kind="pie",
                         figsize=(7, 5),
                         autopct="%1.1f%%"
                         )

plt.title("Keyword Percentage", size=20)
plt.axis("equal")
plt.legend(labels=df_keyword.index, loc=(0.9, 0.5))
